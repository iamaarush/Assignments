# %% [markdown]
# # Question 1
#
# Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
The five plots we can plot using Seaborn library are :-

1. scatterplot() - scatterplots are use to observe relationship between variables and uses dots to represent the relationship
between them.

2. displot() - displot is use for univariant set of observations and visualizes it through a histogram.

3. barplot() - barplot represents an estimate of central tendency for a numeric variable with the height of each rectangle 
and provide some indication of the uncertainity around that estimate using error bars.

4. boxplot() - boxplot helps to maintain the distribution of quantitative data in such a way that it facilitates the 
comparisons between variables or across level of a categorical variable.

5. jointplot() - joint plot draw a plot of two variables with bivariate and univariate graphs.

# %% [markdown]
# # Question 2
#
# Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %%
import seaborn as sns

fmri = sns.load_dataset('fmri')

sns.lineplot(x = "timepoint" , y = "signal" , data = fmri ,hue= "event" , style="region")
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Question 3
#
# Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %%
import seaborn as sns 

titanic = sns.load_dataset("titanic")

sns.boxplot(x = "pclass" , y = "age" , data = titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x = "pclass" , y = "fare" , data = titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# # Question 4
#
# Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
import seaborn as sns
diamond = sns.load_dataset("diamonds")

sns.histplot(x = "price" , data = diamond , hue = "cut")
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %% [markdown]
# # Question 5
#
# Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
import seaborn as sns

iris = sns.load_dataset("iris")

sns.pairplot(iris , hue="species")

# %% [markdown]
# # Question 6
#
# Use the "flights" dataset from seaborn to plot a heatmap.

# %%
import seaborn as sns

flights = sns.load_dataset("flights")

flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight_matrix = flights.pivot(index="year" , columns="month" , values="passengers")
flight_matrix.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
sns.heatmap(flight_matrix ,cmap="YlGnBu", annot=True , fmt= "d" , linewidths=.5 , linecolor="Black").set(title = "Flights per month")
# Out:
# [Text(0.5, 1.0, 'Flights per month')]
